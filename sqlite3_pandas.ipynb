# %%
import pandas as pd
import sqlite3

weather = pd.read_csv(
    "http://www.gagolewski.com/resources/data/nycflights13_weather.csv.gz",
                          comment="#")
flights = pd.read_csv(
    "http://www.gagolewski.com/resources/data/nycflights13_flights.csv.gz",
                          comment="#")
airports = pd.read_csv(
    "http://www.gagolewski.com/resources/data/nycflights13_airports.csv.gz",
                          comment="#")
airlines = pd.read_csv(
    "http://www.gagolewski.com/resources/data/nycflights13_airlines.csv.gz",
                          comment="#")
planes = pd.read_csv(
    "http://www.gagolewski.com/resources/data/nycflights13_planes.csv.gz",
                          comment="#")

# %%
conn = sqlite3.connect('nycflights.db')

# %%
# conn.execute("""
# *insert query here*
# """)

# %%
planes.to_sql('planes', conn)#pandas created the table, and issues a few config settings to make rows and columns
flights.to_sql('flights', conn)
airlines.to_sql('airlines', conn)
weather.to_sql('weather', conn)
airports.to_sql('airports', conn)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-a2e437b308e9> in <module>()
# ----> 1 planes.to_sql('planes', conn)#pandas created the table, and issues a few config settings to make rows and columns
#       2 flights.to_sql('flights', conn)
#       3 airlines.to_sql('airlines', conn)
#       4 weather.to_sql('weather', conn)
#       5 airports.to_sql('airports', conn)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    2125         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2126                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2127                    dtype=dtype)
#    2128
#    2129     def to_pickle(self, path, compression='infer',
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     448     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     449                       index_label=index_label, schema=schema,
# --> 450                       chunksize=chunksize, dtype=dtype)
#     451
#     452
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype)
#    1500                             if_exists=if_exists, index_label=index_label,
#    1501                             dtype=dtype)
# -> 1502         table.create()
#    1503         table.insert(chunksize)
#    1504
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/sql.py in create(self)
#     561         if self.exists():
#     562             if self.if_exists == 'fail':
# --> 563                 raise ValueError("Table '%s' already exists." % self.name)
#     564             elif self.if_exists == 'replace':
#     565                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'planes' already exists.

# %%
# !ls
# Out:
# data			  nycflights.db       sqlite3_pandas.ipynb
# numpy_data_science.ipynb  pandas_contd.ipynb
# numpy_tensors.ipynb	  pandas.ipynb

# %%
pd.read_sql_query("""
    SELECT * FROM PLANES WHERE seats > 400
""", conn)
# Out:
#    index tailnum    year                     type manufacturer    model  \
# 0   2109  N670US  1990.0  Fixed wing multi engine       BOEING  747-451
#
#    engines  seats speed     engine
# 0        4    450  None  Turbo-jet

# %% [markdown]
# 1. SELECT DISTINCT engine FROM planes
# 2. SELECT DISTINCT type, engine FROM planes
# 3. SELECT COUNT(*), engine FROM planes GROUP BY engine
# 4. SELECT COUNT(*), engine, type FROM planes GROUP BY engine, type
# 5. SELECT MIN(year), AVG(year), MAX(year), engine, manufacturer FROM planes GROUP BY engine, manufacturer

# %%
engines = planes['engine'].unique()

# %%
engines
# Out:
# array(['Turbo-fan', 'Turbo-jet', 'Reciprocating', '4 Cycle',
#        'Turbo-shaft', 'Turbo-prop'], dtype=object)

# %%
planes['type, engine'] = (planes['type'] + ' ' + planes['engine'])

# %%
type_engine = planes['type, engine'].unique()

# %%
type_engine
# Out:
# array(['Fixed wing multi engine Turbo-fan',
#        'Fixed wing multi engine Turbo-jet',
#        'Fixed wing single engine Reciprocating',
#        'Fixed wing multi engine Reciprocating',
#        'Fixed wing single engine 4 Cycle', 'Rotorcraft Turbo-shaft',
#        'Fixed wing multi engine Turbo-prop'], dtype=object)

# %%
planes.groupby('engine').size().rename('count').reset_index()
# Out:
#           engine  count
# 0        4 Cycle      2
# 1  Reciprocating     28
# 2      Turbo-fan   2750
# 3      Turbo-jet    535
# 4     Turbo-prop      2
# 5    Turbo-shaft      5

# %%
planes.groupby(['engine', 'type'])['type, engine'].count().rename('count').reset_index()
# Out:
#           engine                      type  count
# 0        4 Cycle  Fixed wing single engine      2
# 1  Reciprocating   Fixed wing multi engine      5
# 2  Reciprocating  Fixed wing single engine     23
# 3      Turbo-fan   Fixed wing multi engine   2750
# 4      Turbo-jet   Fixed wing multi engine    535
# 5     Turbo-prop   Fixed wing multi engine      2
# 6    Turbo-shaft                Rotorcraft      5

# %%
# !mv /home/mathlizard/Downloads/Marek-Day3.ipynb .

# %%
#5. SELECT MIN(year), AVG(year), MAX(year), engine, manufacturer FROM planes GROUP BY engine, manufacturer

planes.groupby(['engine', 'manufacturer']).year.agg(['min', 'max', 'mean']).reset_index().dropna()
# Out:
#            engine                   manufacturer     min     max         mean
# 0         4 Cycle                         CESSNA  1975.0  1975.0  1975.000000
# 3   Reciprocating             AVIAT AIRCRAFT INC  2007.0  2007.0  2007.000000
# 5   Reciprocating                         CESSNA  1959.0  1983.0  1971.142857
# 6   Reciprocating             CIRRUS DESIGN CORP  2007.0  2007.0  2007.000000
# 7   Reciprocating                    DEHAVILLAND  1959.0  1959.0  1959.000000
# 8   Reciprocating                        DOUGLAS  1956.0  1956.0  1956.000000
# 9   Reciprocating                 FRIEDEMANN JON  2007.0  2007.0  2007.000000
# 11  Reciprocating                   KILDALL GARY  1985.0  1985.0  1985.000000
# 13  Reciprocating                LEBLANC GLENN T  1985.0  1985.0  1985.000000
# 14  Reciprocating                     MARZ BARRY  1993.0  1993.0  1993.000000
# 16  Reciprocating                          PIPER  1968.0  1980.0  1976.400000
# 17  Reciprocating                   STEWART MACO  1985.0  1985.0  1985.000000
# 18      Turbo-fan                         AIRBUS  2002.0  2013.0  2007.281734
# 19      Turbo-fan               AIRBUS INDUSTRIE  1992.0  2013.0  1998.599251
# 20      Turbo-fan         AVIONS MARCEL DASSAULT  1986.0  1986.0  1986.000000
# 21      Turbo-fan                         BOEING  1965.0  2013.0  2001.210400
# 22      Turbo-fan                 BOMBARDIER INC  1998.0  2013.0  2004.486188
# 23      Turbo-fan                       CANADAIR  1997.0  1998.0  1997.333333
# 24      Turbo-fan                         CESSNA  1979.0  1979.0  1979.000000
# 25      Turbo-fan                        EMBRAER  1998.0  2013.0  2003.613014
# 26      Turbo-fan           GULFSTREAM AEROSPACE  1992.0  1992.0  1992.000000
# 28      Turbo-fan              MCDONNELL DOUGLAS  1986.0  1997.0  1989.704545
# 29      Turbo-fan  MCDONNELL DOUGLAS AIRCRAFT CO  1987.0  1993.0  1989.737864
# 30      Turbo-jet                         AIRBUS  2002.0  2002.0  2002.000000
# 31      Turbo-jet               AIRBUS INDUSTRIE  1989.0  2004.0  1997.439024
# 32      Turbo-jet                         BOEING  1984.0  2005.0  1996.368272
# 33      Turbo-jet                   CANADAIR LTD  1974.0  1974.0  1974.000000
# 34      Turbo-jet                        EMBRAER  1999.0  1999.0  1999.000000
# 35      Turbo-jet           GULFSTREAM AEROSPACE  1976.0  1976.0  1976.000000
# 36      Turbo-jet              MCDONNELL DOUGLAS  1975.0  1998.0  1990.714286
# 37      Turbo-jet  MCDONNELL DOUGLAS CORPORATION  1991.0  1992.0  1991.928571
# 38     Turbo-prop                          BEECH  1967.0  1972.0  1969.500000
# 39    Turbo-shaft                     AGUSTA SPA  2001.0  2001.0  2001.000000
# 40    Turbo-shaft                           BELL  1975.0  1994.0  1984.500000
# 41    Turbo-shaft         ROBINSON HELICOPTER CO  2012.0  2012.0  2012.000000
# 42    Turbo-shaft                       SIKORSKY  1985.0  1985.0  1985.000000

# %% [markdown]
# SELECT * FROM planes WHERE speed IS NOT NULL
# SELECT tailnum FROM planes WHERE seats BETWEEN 150 AND 190 AND year >= 2012
# SELECT * FROM planes WHERE manufacturer IN ("BOEING", "AIRBUS", "EMBRAER") AND seats>390
# SELECT DISTINCT year, seats FROM planes WHERE year >= 2012 ORDER BY year ASC, seats DESC
# SELECT DISTINCT year, seats FROM planes WHERE year >= 2012 ORDER BY seats DESC, year ASC
# SELECT manufacturer, COUNT(*) FROM planes WHERE seats > 200 GROUP BY manufacturer

# %%
len(planes)
# Out:
# 3322

# %%
len(planes['speed'])
# Out:
# 3322

# %%
planes = planes.drop(['mean_year', 'min_year', 'max_year'], axis=1)

# %%
planes.loc[planes['speed'].notnull()].head()
# Out:
#      tailnum    year                      type manufacturer      model  \
# 424   N201AA  1959.0  Fixed wing single engine       CESSNA        150
# 427   N202AA  1980.0   Fixed wing multi engine       CESSNA       421C
# 821   N350AA  1980.0   Fixed wing multi engine        PIPER  PA-31-350
# 893   N364AA  1973.0   Fixed wing multi engine       CESSNA       310Q
# 1027  N378AA  1963.0  Fixed wing single engine       CESSNA       172E
#
#       engines  seats  speed         engine  \
# 424         1      2   90.0  Reciprocating
# 427         2      8   90.0  Reciprocating
# 821         2      8  162.0  Reciprocating
# 893         2      6  167.0  Reciprocating
# 1027        1      4  105.0  Reciprocating
#
#                                 type, engine
# 424   Fixed wing single engine Reciprocating
# 427    Fixed wing multi engine Reciprocating
# 821    Fixed wing multi engine Reciprocating
# 893    Fixed wing multi engine Reciprocating
# 1027  Fixed wing single engine Reciprocating

# %%
planes['tailnum'].loc[(planes['seats'].between(150, 190)) & (planes['year'] >= 2012)].reset_index()
# Out:
#    index tailnum
# 0    875  N361VA
# 1   2745  N849VA
# 2   2754  N851VA
# 3   2757  N852VA
# 4   2761  N853VA
# 5   2766  N854VA
# 6   2769  N855VA

# %%
#SELECT * FROM planes WHERE manufacturer IN ("BOEING", "AIRBUS", "EMBRAER") AND seats>390
planes.loc[(planes['manufacturer'].isin(["BOEING", "AIRBUS", "EMBRAER"])) & (planes['seats'] >390)].reset_index()
# Out:
#     index tailnum    year                     type manufacturer    model  \
# 0     439  N206UA  1999.0  Fixed wing multi engine       BOEING  777-222
# 1     484  N228UA  2002.0  Fixed wing multi engine       BOEING  777-222
# 2     577  N272AT     NaN  Fixed wing multi engine       BOEING  777-200
# 3    1708  N57016  2000.0  Fixed wing multi engine       BOEING  777-224
# 4    2109  N670US  1990.0  Fixed wing multi engine       BOEING  747-451
# 5    2441  N77012  1999.0  Fixed wing multi engine       BOEING  777-224
# 6    2485  N777UA  1995.0  Fixed wing multi engine       BOEING  777-222
# 7    2494  N78003  1998.0  Fixed wing multi engine       BOEING  777-224
# 8    2495  N78013  1999.0  Fixed wing multi engine       BOEING  777-224
# 9    2519  N787UA  1997.0  Fixed wing multi engine       BOEING  777-222
# 10   2804  N862DA  1999.0  Fixed wing multi engine       BOEING  777-232
# 11   2806  N863DA  1999.0  Fixed wing multi engine       BOEING  777-232
# 12   2809  N865DA  1999.0  Fixed wing multi engine       BOEING  777-232
#
#     engines  seats  speed     engine                       type, engine  \
# 0         2    400    NaN  Turbo-fan  Fixed wing multi engine Turbo-fan
# 1         2    400    NaN  Turbo-fan  Fixed wing multi engine Turbo-fan
# 2         2    400    NaN  Turbo-jet  Fixed wing multi engine Turbo-jet
# 3         2    400    NaN  Turbo-fan  Fixed wing multi engine Turbo-fan
# 4         4    450    NaN  Turbo-jet  Fixed wing multi engine Turbo-jet
# 5         2    400    NaN  Turbo-fan  Fixed wing multi engine Turbo-fan
# 6         2    400    NaN  Turbo-fan  Fixed wing multi engine Turbo-fan
# 7         2    400    NaN  Turbo-fan  Fixed wing multi engine Turbo-fan
# 8         2    400    NaN  Turbo-fan  Fixed wing multi engine Turbo-fan
# 9         2    400    NaN  Turbo-fan  Fixed wing multi engine Turbo-fan
# 10        2    400    NaN  Turbo-jet  Fixed wing multi engine Turbo-jet
# 11        2    400    NaN  Turbo-jet  Fixed wing multi engine Turbo-jet
# 12        2    400    NaN  Turbo-jet  Fixed wing multi engine Turbo-jet
#
#     mean_year  min_year  max_year
# 0         NaN       NaN       NaN
# 1         NaN       NaN       NaN
# 2         NaN       NaN       NaN
# 3         NaN       NaN       NaN
# 4         NaN       NaN       NaN
# 5         NaN       NaN       NaN
# 6         NaN       NaN       NaN
# 7         NaN       NaN       NaN
# 8         NaN       NaN       NaN
# 9         NaN       NaN       NaN
# 10        NaN       NaN       NaN
# 11        NaN       NaN       NaN
# 12        NaN       NaN       NaN

# %%
#SELECT DISTINCT year, seats FROM planes WHERE year >= 2012 ORDER BY year ASC, seats DESC
planes.loc[planes['year'] >=2012, ['year', 'seats']].drop_duplicates().sort_values(['year','seats'], ascending=[True, False]).reset_index(drop=True)
# Out:
#       year  seats
# 0   2012.0    379
# 1   2012.0    377
# 2   2012.0    260
# 3   2012.0    222
# 4   2012.0    200
# 5   2012.0    191
# 6   2012.0    182
# 7   2012.0    149
# 8   2012.0    140
# 9   2012.0     20
# 10  2012.0      5
# 11  2013.0    379
# 12  2013.0    377
# 13  2013.0    222
# 14  2013.0    200
# 15  2013.0    199
# 16  2013.0    191
# 17  2013.0    182
# 18  2013.0    140
# 19  2013.0     95
# 20  2013.0     20

# %%
planes.loc[planes['year'] >=2012, ['year', 'seats']][::-1].drop_duplicates().sort_values(['year','seats'], ascending=[True, False][::-1]).reset_index(drop=True)
# Out:
#       year  seats
# 0   2013.0     20
# 1   2013.0     95
# 2   2013.0    140
# 3   2013.0    182
# 4   2013.0    191
# 5   2013.0    199
# 6   2013.0    200
# 7   2013.0    222
# 8   2013.0    377
# 9   2013.0    379
# 10  2012.0      5
# 11  2012.0     20
# 12  2012.0    140
# 13  2012.0    149
# 14  2012.0    182
# 15  2012.0    191
# 16  2012.0    200
# 17  2012.0    222
# 18  2012.0    260
# 19  2012.0    377
# 20  2012.0    379

# %%
# 11. SELECT manufacturer, COUNT(*) FROM planes WHERE seats > 200 GROUP BY manufacturer
planes.groupby('manufacturer').count().reset_index().loc[planes['seats']>90,:]
# Out:
#               manufacturer  tailnum  year  type  model  engines  seats  speed  \
# 1                   AIRBUS      336   328   336    336      336    336      0
# 2         AIRBUS INDUSTRIE      400   390   400    400      400    400      0
# 3    AMERICAN AIRCRAFT INC        2     0     2      2        2      2      0
# 5   AVIONS MARCEL DASSAULT        1     1     1      1        1      1      0
# 6            BARKER JACK L        1     0     1      1        1      1      0
# 7                    BEECH        2     2     2      2        2      2      1
# 8                     BELL        2     2     2      2        2      2      1
# 9                   BOEING     1630  1603  1630   1630     1630   1630      0
# 33                SIKORSKY        1     1     1      1        1      1      0
# 34            STEWART MACO        2     1     2      2        2      2      0
#
#     engine  type, engine
# 1      336           336
# 2      400           400
# 3        2             2
# 5        1             1
# 6        1             1
# 7        2             2
# 8        2             2
# 9     1630          1630
# 33       1             1
# 34       2             2

# %%
# 12. SELECT manufacturer, COUNT(*) FROM planes GROUP BY manufacturer HAVING COUNT(*) > 10
df = planes.groupby('manufacturer').size().rename('count').reset_index()
df.loc[df['count'] > 10]
# Out:
#                      manufacturer  count
# 1                          AIRBUS    336
# 2                AIRBUS INDUSTRIE    400
# 9                          BOEING   1630
# 10                 BOMBARDIER INC    368
# 17                        EMBRAER    299
# 27              MCDONNELL DOUGLAS    120
# 28  MCDONNELL DOUGLAS AIRCRAFT CO    103
# 29  MCDONNELL DOUGLAS CORPORATION     14

# %%
#13. SELECT manufacturer, COUNT(*) FROM planes WHERE seats > 200 GROUP BY manufacturer HAVING COUNT(*) > 10
df = planes.loc[planes['seats'] > 200].groupby('manufacturer').size().rename('count').reset_index()
df.loc[(df['count'] > 10)]
# Out:
#   manufacturer  count
# 0       AIRBUS     66
# 2       BOEING    225

# %% [markdown]
# 11. SELECT manufacturer, COUNT(*) FROM planes WHERE seats > 200 GROUP BY manufacturer
# 12. SELECT manufacturer, COUNT(*) FROM planes GROUP BY manufacturer HAVING COUNT(*) > 10
# 13. SELECT manufacturer, COUNT(*) FROM planes WHERE seats > 200 GROUP BY manufacturer HAVING COUNT(*) > 10
# 14. SELECT manufacturer, COUNT(*) AS howmany FROM planes GROUP BY manufacturer ORDER BY howmany DESC LIMIT 5
# 15. SELECT * FROM flights LEFT JOIN planes ON flights.tailnum=planes.tailnum
#
# 16.
#
#   ```
#   SELECT planes.*, airlines.* FROM
#    (SELECT DISTINCT carrier, tailnum FROM flights) AS cartail
#   INNER JOIN planes ON cartail.tailnum=planes.tailnum
#   INNER JOIN airlines ON cartail.carrier=airlines.carrier
#   ```
#
# 17.
#
#   ```
#   SELECT flights2.*, weather2.atemp, weather2.ahumid, weather2.apressure FROM
#      (SELECT * FROM flights WHERE origin='EWR') AS flights2
#   LEFT JOIN
#      (SELECT year, month, day, AVG(temp) AS atemp,
#        AVG(humid) AS ahumid, AVG(pressure) AS apressure
#       FROM weather WHERE origin='EWR' GROUP BY year, month, day) AS weather2
#   ON flights2.year=weather2.year
#     AND flights2.month=weather2.month
#     AND flights2.day=weather2.day
#   ```

# %%
#14. SELECT manufacturer, COUNT(*) AS howmany FROM planes GROUP BY manufacturer ORDER BY howmany DESC LIMIT 5
planes.groupby('manufacturer').size().rename('howmany').reset_index().sort_values('howmany',ascending=False).head(5)
# Out:
#         manufacturer  howmany
# 9             BOEING     1630
# 2   AIRBUS INDUSTRIE      400
# 10    BOMBARDIER INC      368
# 1             AIRBUS      336
# 17           EMBRAER      299

# %%
#15. SELECT * FROM flights LEFT JOIN planes ON flights.tailnum=planes.tailnum
flights.merge(planes, on="tailnum",how='left').head(5)
# Out:
#    year_x  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0    2013      1    1     517.0             515        2.0     830.0
# 1    2013      1    1     533.0             529        4.0     850.0
# 2    2013      1    1     542.0             540        2.0     923.0
# 3    2013      1    1     544.0             545       -1.0    1004.0
# 4    2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier                ...                  \
# 0             819       11.0      UA                ...
# 1             830       20.0      UA                ...
# 2             850       33.0      AA                ...
# 3            1022      -18.0      B6                ...
# 4             837      -25.0      DL                ...
#
#              time_hour  year_y                     type manufacturer  \
# 0  2013-01-01 05:00:00  1999.0  Fixed wing multi engine       BOEING
# 1  2013-01-01 05:00:00  1998.0  Fixed wing multi engine       BOEING
# 2  2013-01-01 05:00:00  1990.0  Fixed wing multi engine       BOEING
# 3  2013-01-01 05:00:00  2012.0  Fixed wing multi engine       AIRBUS
# 4  2013-01-01 06:00:00  1991.0  Fixed wing multi engine       BOEING
#
#       model  engines  seats  speed     engine  \
# 0   737-824      2.0  149.0    NaN  Turbo-fan
# 1   737-824      2.0  149.0    NaN  Turbo-fan
# 2   757-223      2.0  178.0    NaN  Turbo-fan
# 3  A320-232      2.0  200.0    NaN  Turbo-fan
# 4   757-232      2.0  178.0    NaN  Turbo-fan
#
#                         type, engine
# 0  Fixed wing multi engine Turbo-fan
# 1  Fixed wing multi engine Turbo-fan
# 2  Fixed wing multi engine Turbo-fan
# 3  Fixed wing multi engine Turbo-fan
# 4  Fixed wing multi engine Turbo-fan
#
# [5 rows x 28 columns]

# %%
#  ```
#   SELECT planes.*, airlines.* FROM
#    (SELECT DISTINCT carrier, tailnum FROM flights) AS cartail
#   INNER JOIN planes ON cartail.tailnum=planes.tailnum
#   INNER JOIN airlines ON cartail.carrier=airlines.carrier
#   ```

# %%
pd.read_sql_query("""
    SELECT * FROM PLANES WHERE seats > 400
""", conn)
